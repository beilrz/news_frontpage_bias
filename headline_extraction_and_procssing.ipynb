# %% [markdown]
# # part 1: process element into html_element

# %%
import pandas as pd
import json

# %%
# convert media name to bias rating
media_df = pd.read_csv("../data/core_results.csv")

def get_bias_leaning(media_name, media_df = media_df):
    media_name = media_name.replace("-", " ")
    result = media_df.loc[media_df['news'] == media_name, 'bias'].values
    return result[0]

# %%
# read json file

def read_json(path):
    # return [dict, name, date]
    with open(path, "r") as infile:
        j = json.load(infile)
    
    name_and_date = path.split("/")[-1].split('_')
    name = name_and_date[0]
    date = name_and_date[1][:-5] # before .json
    
    return [j, name, date]

# %%
read_json("../data/sites_jsons/json/ABC-News-(Online)_20220101000143.json")
# Out:
# [[[{'tag_name': 'span',
#     'text': 'ABC News',
#     'location': {'x': 272, 'y': 7233},
#     'size': {'height': 0, 'width': 0},
#     'NER': [],
#     'SA': {}},
#    [{'tag_name': 'h4',
#      'text': 'VIDEO',
#      'location': {'x': 432, 'y': 7188},
#      'size': {'height': 15, 'width': 48},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'h4',
#      'text': 'LIVE',
#      'location': {'x': 524, 'y': 7188},
#      'size': {'height': 15, 'width': 34},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'h4',
#      'text': 'SHOWS',
#      'location': {'x': 602, 'y': 7188},
#      'size': {'height': 15, 'width': 57},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'h4',
#      'text': 'CORONAVIRUS',
#      'location': {'x': 702, 'y': 7188},
#      'size': {'height': 15, 'width': 112},
#      'NER': [],
#      'SA': {}}],
#    {'tag_name': 'button',
#     'text': 'LOG IN',
#     'location': {'x': 1580, 'y': 7187},
#     'size': {'height': 16, 'width': 52},
#     'NER': [],
#     'SA': {}}],
#   [[{'tag_name': 'h2',
#      'text': 'Biden threaten Putin with sanctions over Ukraine',
#      'location': {'x': 272, 'y': 167},
#      'size': {'height': 19, 'width': 325},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.9978671',
#        'index': 1,
#        'word': 'B',
#        'start': 0,
#        'end': 1},
#       {'entity': 'B-PER',
#        'score': '0.8995158',
#        'index': 2,
#        'word': '##iden',
#        'start': 1,
#        'end': 5},
#       {'entity': 'B-PER',
#        'score': '0.99745303',
#        'index': 4,
#        'word': 'Putin',
#        'start': 15,
#        'end': 20},
#       {'entity': 'B-LOC',
#        'score': '0.99974483',
#        'index': 8,
#        'word': 'Ukraine',
#        'start': 41,
#        'end': 48}],
#      'SA': {'pos': 0.1687677949666977, 'neg': 0.8312321901321411}},
#     {'tag_name': 'h2',
#      'text': 'Coaches made teen eat pizza despite religion: Suit',
#      'location': {'x': 272, 'y': 207},
#      'size': {'height': 19, 'width': 324},
#      'NER': [],
#      'SA': {'pos': 0.13421954214572906, 'neg': 0.8657805323600769}},
#     {'tag_name': 'h2',
#      'text': 'Suspect arrested in shooting of police officers',
#      'location': {'x': 272, 'y': 247},
#      'size': {'height': 19, 'width': 297},
#      'NER': [],
#      'SA': {'pos': 0.09297964721918106, 'neg': 0.9070203900337219}},
#     {'tag_name': 'h2',
#      'text': 'DOJ drops case against cops in Epstein suicide',
#      'location': {'x': 272, 'y': 287},
#      'size': {'height': 19, 'width': 309},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.9989704',
#        'index': 1,
#        'word': 'D',
#        'start': 0,
#        'end': 1},
#       {'entity': 'I-ORG',
#        'score': '0.98680216',
#        'index': 2,
#        'word': '##O',
#        'start': 1,
#        'end': 2},
#       {'entity': 'I-ORG',
#        'score': '0.910315',
#        'index': 3,
#        'word': '##J',
#        'start': 2,
#        'end': 3},
#       {'entity': 'B-PER',
#        'score': '0.9993648',
#        'index': 9,
#        'word': 'E',
#        'start': 31,
#        'end': 32},
#       {'entity': 'B-PER',
#        'score': '0.97833997',
#        'index': 10,
#        'word': '##ps',
#        'start': 32,
#        'end': 34},
#       {'entity': 'B-PER',
#        'score': '0.949411',
#        'index': 11,
#        'word': '##tein',
#        'start': 34,
#        'end': 38}],
#      'SA': {'pos': 0.1945149451494217, 'neg': 0.8054850697517395}},
#     {'tag_name': 'h2',
#      'text': 'Powerball jackpot raised to $500 million',
#      'location': {'x': 272, 'y': 327},
#      'size': {'height': 19, 'width': 263},
#      'NER': [],
#      'SA': {'pos': 0.8186860680580139, 'neg': 0.1813139170408249}},
#     {'tag_name': 'h2',
#      'text': 'Over 65 shots fired on busy Philadelphia street',
#      'location': {'x': 272, 'y': 367},
#      'size': {'height': 19, 'width': 305},
#      'NER': [{'entity': 'B-LOC',
#        'score': '0.9996049',
#        'index': 7,
#        'word': 'Philadelphia',
#        'start': 28,
#        'end': 40}],
#      'SA': {'pos': 0.12191345542669296, 'neg': 0.878086507320404}},
#     {'tag_name': 'h2',
#      'text': "Revelers await return to NYC's Times Square",
#      'location': {'x': 272, 'y': 407},
#      'size': {'height': 19, 'width': 291},
#      'NER': [{'entity': 'B-LOC',
#        'score': '0.9993806',
#        'index': 9,
#        'word': 'NYC',
#        'start': 25,
#        'end': 28},
#       {'entity': 'B-LOC',
#        'score': '0.99768853',
#        'index': 12,
#        'word': 'Times',
#        'start': 31,
#        'end': 36},
#       {'entity': 'I-LOC',
#        'score': '0.99903935',
#        'index': 13,
#        'word': 'Square',
#        'start': 37,
#        'end': 43}],
#      'SA': {'pos': 0.8480405211448669, 'neg': 0.15195947885513306}},
#     {'tag_name': 'h2',
#      'text': "Gov. gives 'Jeopardy' contestant a 2nd chance",
#      'location': {'x': 272, 'y': 447},
#      'size': {'height': 19, 'width': 299},
#      'NER': [{'entity': 'B-MISC',
#        'score': '0.99329513',
#        'index': 6,
#        'word': 'Je',
#        'start': 12,
#        'end': 14},
#       {'entity': 'I-MISC',
#        'score': '0.7208246',
#        'index': 7,
#        'word': '##op',
#        'start': 14,
#        'end': 16},
#       {'entity': 'I-MISC',
#        'score': '0.6488832',
#        'index': 8,
#        'word': '##ard',
#        'start': 16,
#        'end': 19},
#       {'entity': 'I-MISC',
#        'score': '0.9375317',
#        'index': 9,
#        'word': '##y',
#        'start': 19,
#        'end': 20}],
#      'SA': {'pos': 0.7166122198104858, 'neg': 0.2833877503871918}},
#     {'tag_name': 'h2',
#      'text': "Tops school's annual banished words list",
#      'location': {'x': 272, 'y': 487},
#      'size': {'height': 19, 'width': 270},
#      'NER': [],
#      'SA': {'pos': 0.1250007003545761, 'neg': 0.8749993443489075}},
#     {'tag_name': 'h2',
#      'text': 'Roe lawyer helped redefine abortion rights',
#      'location': {'x': 272, 'y': 527},
#      'size': {'height': 19, 'width': 278},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.9316157',
#        'index': 1,
#        'word': 'Roe',
#        'start': 0,
#        'end': 3}],
#      'SA': {'pos': 0.9372395277023315, 'neg': 0.06276044994592667}},
#     {'tag_name': 'h2',
#      'text': '2 killed when train hits car going around crossing',
#      'location': {'x': 272, 'y': 567},
#      'size': {'height': 19, 'width': 325},
#      'NER': [],
#      'SA': {'pos': 0.03207630291581154, 'neg': 0.967923641204834}},
#     {'tag_name': 'h2',
#      'text': '$15B from Gates tops 2021 biggest gift list',
#      'location': {'x': 272, 'y': 607},
#      'size': {'height': 19, 'width': 271},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.9162364',
#        'index': 5,
#        'word': 'Gates',
#        'start': 10,
#        'end': 15}],
#      'SA': {'pos': 0.8448543548583984, 'neg': 0.15514568984508514}}],
#    [[{'tag_name': 'h4',
#       'text': "'Miraculous': No casualties reported in devastating Colorado wildfires",
#       'location': {'x': 659, 'y': 480},
#       'size': {'height': 56, 'width': 532},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.99970144',
#         'index': 12,
#         'word': 'Colorado',
#         'start': 52,
#         'end': 60}],
#       'SA': {'pos': 0.9558232426643372, 'neg': 0.04417675733566284}},
#      [{'tag_name': 'p',
#        'text': 'Hundreds of homes were destroyed in Superior, Colorado.',
#        'location': {'x': 659, 'y': 547},
#        'size': {'height': 28, 'width': 532},
#        'NER': [{'entity': 'B-LOC',
#          'score': '0.9936547',
#          'index': 7,
#          'word': 'Superior',
#          'start': 36,
#          'end': 44},
#         {'entity': 'B-LOC',
#          'score': '0.9994374',
#          'index': 9,
#          'word': 'Colorado',
#          'start': 46,
#          'end': 54}],
#        'SA': {'pos': 0.04887913167476654, 'neg': 0.9511208534240723}},
#       {'tag_name': 'div',
#        'text': 'December 31, 2021',
#        'location': {'x': 659, 'y': 575},
#        'size': {'height': 18, 'width': 532},
#        'NER': [],
#        'SA': {}}]],
#     [{'tag_name': 'a',
#       'text': 'Hundreds of homes lost amid fast-spreading fires',
#       'location': {'x': 669, 'y': 602},
#       'size': {'height': 20, 'width': 327},
#       'NER': [],
#       'SA': {'pos': 0.028314964845776558, 'neg': 0.971684992313385}},
#      {'tag_name': 'a',
#       'text': 'How climate change played key role in disastrous Colorado wildfires',
#       'location': {'x': 669, 'y': 636},
#       'size': {'height': 20, 'width': 449},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9997198',
#         'index': 9,
#         'word': 'Colorado',
#         'start': 49,
#         'end': 57}],
#       'SA': {'pos': 0.4383818507194519, 'neg': 0.5616181492805481}}]],
#    [[[{'tag_name': 'span',
#        'text': '24/7 Coverage of Breaking News and Live Events.',
#        'location': {'x': 1240, 'y': 415},
#        'size': {'height': 13, 'width': 229},
#        'NER': [{'entity': 'B-MISC',
#          'score': '0.99529904',
#          'index': 7,
#          'word': 'Breaking',
#          'start': 17,
#          'end': 25},
#         {'entity': 'I-MISC',
#          'score': '0.998264',
#          'index': 8,
#          'word': 'News',
#          'start': 26,
#          'end': 30},
#         {'entity': 'B-MISC',
#          'score': '0.7176889',
#          'index': 10,
#          'word': 'Live',
#          'start': 35,
#          'end': 39},
#         {'entity': 'I-MISC',
#          'score': '0.91352296',
#          'index': 11,
#          'word': 'Events',
#          'start': 40,
#          'end': 46}],
#        'SA': {'pos': 0.7173527479171753, 'neg': 0.2826472818851471}},
#       {'tag_name': 'span',
#        'text': 'ON NOW • LIVE',
#        'location': {'x': 1212, 'y': 443},
#        'size': {'height': 16, 'width': 83},
#        'NER': [],
#        'SA': {}}],
#      {'tag_name': 'span',
#       'text': "New Year's Eve: Times Square Ball Drop",
#       'location': {'x': 1212, 'y': 461},
#       'size': {'height': 19, 'width': 234},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.8337462',
#         'index': 7,
#         'word': 'Times',
#         'start': 16,
#         'end': 21},
#        {'entity': 'I-LOC',
#         'score': '0.8220734',
#         'index': 8,
#         'word': 'Square',
#         'start': 22,
#         'end': 28},
#        {'entity': 'I-LOC',
#         'score': '0.36492872',
#         'index': 9,
#         'word': 'Ball',
#         'start': 29,
#         'end': 33},
#        {'entity': 'I-MISC',
#         'score': '0.46832666',
#         'index': 10,
#         'word': 'Drop',
#         'start': 34,
#         'end': 38}],
#       'SA': {'pos': 0.3921104371547699, 'neg': 0.6078895330429077}}],
#     [{'tag_name': 'h4',
#       'text': "As governor commutes trucker's sentence, DA vows to release new information from case",
#       'location': {'x': 1212, 'y': 500},
#       'size': {'height': 42, 'width': 421},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.99558735',
#         'index': 12,
#         'word': 'D',
#         'start': 41,
#         'end': 42},
#        {'entity': 'I-ORG',
#         'score': '0.94445056',
#         'index': 13,
#         'word': '##A',
#         'start': 42,
#         'end': 43}],
#       'SA': {'pos': 0.2995235323905945, 'neg': 0.7004764676094055}},
#      [{'tag_name': 'p',
#        'text': 'Rogel Aguilera-Mederos\' attorneys said the move is "politically" motivated.',
#        'location': {'x': 1212, 'y': 550},
#        'size': {'height': 34, 'width': 279},
#        'NER': [{'entity': 'B-PER',
#          'score': '0.9991571',
#          'index': 1,
#          'word': 'R',
#          'start': 0,
#          'end': 1},
#         {'entity': 'I-PER',
#          'score': '0.74406403',
#          'index': 2,
#          'word': '##ogel',
#          'start': 1,
#          'end': 5},
#         {'entity': 'I-PER',
#          'score': '0.9994886',
#          'index': 3,
#          'word': 'A',
#          'start': 6,
#          'end': 7},
#         {'entity': 'I-PER',
#          'score': '0.99641114',
#          'index': 4,
#          'word': '##gu',
#          'start': 7,
#          'end': 9},
#         {'entity': 'I-PER',
#          'score': '0.9708029',
#          'index': 5,
#          'word': '##iler',
#          'start': 9,
#          'end': 13},
#         {'entity': 'I-PER',
#          'score': '0.96753204',
#          'index': 6,
#          'word': '##a',
#          'start': 13,
#          'end': 14},
#         {'entity': 'B-PER',
#          'score': '0.7546794',
#          'index': 8,
#          'word': 'Me',
#          'start': 15,
#          'end': 17},
#         {'entity': 'I-PER',
#          'score': '0.9774799',
#          'index': 9,
#          'word': '##der',
#          'start': 17,
#          'end': 20},
#         {'entity': 'I-PER',
#          'score': '0.8129618',
#          'index': 10,
#          'word': '##os',
#          'start': 20,
#          'end': 22}],
#        'SA': {'pos': 0.35745763778686523, 'neg': 0.6425423622131348}},
#       {'tag_name': 'div',
#        'text': '2 hours ago',
#        'location': {'x': 1212, 'y': 592},
#        'size': {'height': 17, 'width': 279},
#        'NER': [],
#        'SA': {}}]]]],
#   [[{'tag_name': 'h2',
#      'text': 'Trending video',
#      'location': {'x': 272, 'y': 732},
#      'size': {'height': 15, 'width': 119},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'span',
#       'text': '1:46',
#       'location': {'x': 322, 'y': 913},
#       'size': {'height': 19, 'width': 28},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'span',
#       'text': "Behind the scenes look of the New Year's ball drop",
#       'location': {'x': 292, 'y': 952},
#       'size': {'height': 52, 'width': 390},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.7508519',
#         'index': 7,
#         'word': 'New',
#         'start': 30,
#         'end': 33}],
#       'SA': {'pos': 0.6022826433181763, 'neg': 0.39771732687950134}}],
#     [[{'tag_name': 'span',
#        'text': 'Airline passenger captures bird’s-eye view of Colorado wildfire',
#        'location': {'x': 272, 'y': 1038},
#        'size': {'height': 37, 'width': 357},
#        'NER': [{'entity': 'B-LOC',
#          'score': '0.99974805',
#          'index': 12,
#          'word': 'Colorado',
#          'start': 46,
#          'end': 54}],
#        'SA': {'pos': 0.9822998642921448, 'neg': 0.01770017482340336}},
#       {'tag_name': 'span',
#        'text': '1:02',
#        'location': {'x': 684, 'y': 1049},
#        'size': {'height': 16, 'width': 27},
#        'NER': [],
#        'SA': {}}],
#      [{'tag_name': 'span',
#        'text': 'Rare Siberian tiger, cubs caught on camera',
#        'location': {'x': 272, 'y': 1114},
#        'size': {'height': 20, 'width': 278},
#        'NER': [{'entity': 'B-MISC',
#          'score': '0.99938595',
#          'index': 2,
#          'word': 'Siberian',
#          'start': 5,
#          'end': 13}],
#        'SA': {'pos': 0.9582588076591492, 'neg': 0.041741158813238144}},
#       {'tag_name': 'span',
#        'text': '0:41',
#        'location': {'x': 684, 'y': 1116},
#        'size': {'height': 16, 'width': 27},
#        'NER': [],
#        'SA': {}}],
#      [{'tag_name': 'span',
#        'text': 'Wildfire burns through Colorado family’s backyard',
#        'location': {'x': 272, 'y': 1173},
#        'size': {'height': 20, 'width': 335},
#        'NER': [{'entity': 'B-LOC',
#          'score': '0.9995542',
#          'index': 5,
#          'word': 'Colorado',
#          'start': 23,
#          'end': 31}],
#        'SA': {'pos': 0.975059449672699, 'neg': 0.02494059130549431}},
#       {'tag_name': 'span',
#        'text': '1:50',
#        'location': {'x': 684, 'y': 1176},
#        'size': {'height': 16, 'width': 27},
#        'NER': [],
#        'SA': {}}],
#      [{'tag_name': 'span',
#        'text': "Confetti tested ahead of New Year's Eve celebration in Times Square",
#        'location': {'x': 272, 'y': 1232},
#        'size': {'height': 37, 'width': 350},
#        'NER': [{'entity': 'B-PER',
#          'score': '0.87566996',
#          'index': 1,
#          'word': 'Con',
#          'start': 0,
#          'end': 3},
#         {'entity': 'I-MISC',
#          'score': '0.59498155',
#          'index': 2,
#          'word': '##fe',
#          'start': 3,
#          'end': 5},
#         {'entity': 'B-MISC',
#          'score': '0.9719853',
#          'index': 7,
#          'word': 'New',
#          'start': 25,
#          'end': 28},
#         {'entity': 'I-MISC',
#          'score': '0.842094',
#          'index': 8,
#          'word': 'Year',
#          'start': 29,
#          'end': 33},
#         {'entity': 'I-MISC',
#          'score': '0.6991049',
#          'index': 9,
#          'word': "'",
#          'start': 33,
#          'end': 34},
#         {'entity': 'I-MISC',
#          'score': '0.983053',
#          'index': 10,
#          'word': 's',
#          'start': 34,
#          'end': 35},
#         {'entity': 'I-MISC',
#          'score': '0.8973793',
#          'index': 11,
#          'word': 'Eve',
#          'start': 36,
#          'end': 39},
#         {'entity': 'B-LOC',
#          'score': '0.9979153',
#          'index': 14,
#          'word': 'Times',
#          'start': 55,
#          'end': 60},
#         {'entity': 'I-LOC',
#          'score': '0.99908066',
#          'index': 15,
#          'word': 'Square',
#          'start': 61,
#          'end': 67}],
#        'SA': {'pos': 0.6107404232025146, 'neg': 0.3892594873905182}},
#       {'tag_name': 'span',
#        'text': '1:06',
#        'location': {'x': 684, 'y': 1243},
#        'size': {'height': 16, 'width': 27},
#        'NER': [],
#        'SA': {}}]]],
#    [{'tag_name': 'a',
#      'text': "'Golden Girls' star Betty White dies at 99",
#      'location': {'x': 752, 'y': 1012},
#      'size': {'height': 59, 'width': 389},
#      'NER': [{'entity': 'B-MISC',
#        'score': '0.8197065',
#        'index': 2,
#        'word': 'Golden',
#        'start': 1,
#        'end': 7},
#       {'entity': 'I-MISC',
#        'score': '0.86207867',
#        'index': 3,
#        'word': 'Girls',
#        'start': 8,
#        'end': 13},
#       {'entity': 'B-PER',
#        'score': '0.99956125',
#        'index': 6,
#        'word': 'Betty',
#        'start': 20,
#        'end': 25},
#       {'entity': 'I-PER',
#        'score': '0.9995697',
#        'index': 7,
#        'word': 'White',
#        'start': 26,
#        'end': 31}],
#      'SA': {'pos': 0.06225410848855972, 'neg': 0.9377459287643433}},
#     {'tag_name': 'div',
#      'text': '2 hours ago',
#      'location': {'x': 752, 'y': 1080},
#      'size': {'height': 24, 'width': 400},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'a',
#       'text': 'Ryan Reynolds, Ellen DeGeneres and more stars pay tribute to Betty White',
#       'location': {'x': 775, 'y': 1124},
#       'size': {'height': 37, 'width': 362},
#       'NER': [{'entity': 'B-PER',
#         'score': '0.99973696',
#         'index': 1,
#         'word': 'Ryan',
#         'start': 0,
#         'end': 4},
#        {'entity': 'I-PER',
#         'score': '0.99977046',
#         'index': 2,
#         'word': 'Reynolds',
#         'start': 5,
#         'end': 13},
#        {'entity': 'B-PER',
#         'score': '0.9996331',
#         'index': 4,
#         'word': 'Ellen',
#         'start': 15,
#         'end': 20},
#        {'entity': 'I-PER',
#         'score': '0.999635',
#         'index': 5,
#         'word': 'De',
#         'start': 21,
#         'end': 23},
#        {'entity': 'I-PER',
#         'score': '0.9995485',
#         'index': 6,
#         'word': '##G',
#         'start': 23,
#         'end': 24},
#        {'entity': 'I-PER',
#         'score': '0.9960316',
#         'index': 7,
#         'word': '##ener',
#         'start': 24,
#         'end': 28},
#        {'entity': 'I-PER',
#         'score': '0.9985056',
#         'index': 8,
#         'word': '##es',
#         'start': 28,
#         'end': 30},
#        {'entity': 'B-PER',
#         'score': '0.9985726',
#         'index': 15,
#         'word': 'Betty',
#         'start': 61,
#         'end': 66},
#        {'entity': 'I-PER',
#         'score': '0.99642307',
#         'index': 16,
#         'word': 'White',
#         'start': 67,
#         'end': 72}],
#       'SA': {'pos': 0.9606690406799316, 'neg': 0.03933100774884224}},
#      {'tag_name': 'a',
#       'text': 'SLIDESHOW: Betty White through the years',
#       'location': {'x': 775, 'y': 1172},
#       'size': {'height': 19, 'width': 258},
#       'NER': [{'entity': 'B-PER',
#         'score': '0.9988714',
#         'index': 7,
#         'word': 'Betty',
#         'start': 11,
#         'end': 16},
#        {'entity': 'I-PER',
#         'score': '0.98975986',
#         'index': 8,
#         'word': 'White',
#         'start': 17,
#         'end': 22}],
#       'SA': {'pos': 0.9476006031036377, 'neg': 0.05239936709403992}}],
#     {'tag_name': 'div',
#      'text': 'CBS/Getty Images',
#      'location': {'x': 1103, 'y': 1210},
#      'size': {'height': 11, 'width': 69},
#      'NER': [],
#      'SA': {}}],
#    [{'tag_name': 'a',
#      'text': 'FAA issues warning to travelers amid omicron surge: Delays will continue',
#      'location': {'x': 1213, 'y': 1011},
#      'size': {'height': 59, 'width': 381},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.99826163',
#        'index': 1,
#        'word': 'FAA',
#        'start': 0,
#        'end': 3}],
#      'SA': {'pos': 0.10213024169206619, 'neg': 0.8978697657585144}},
#     {'tag_name': 'div',
#      'text': 'Dec 31',
#      'location': {'x': 1213, 'y': 1079},
#      'size': {'height': 24, 'width': 399},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'a',
#       'text': 'COVID live updates: US breaks weekly COVID-19 case record',
#       'location': {'x': 1236, 'y': 1123},
#       'size': {'height': 19, 'width': 362},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9991941',
#         'index': 7,
#         'word': 'US',
#         'start': 20,
#         'end': 22}],
#       'SA': {'pos': 0.37550708651542664, 'neg': 0.6244929432868958}},
#      {'tag_name': 'a',
#       'text': "Experts urge caution ahead of New Year's Eve festivities as COVID surge intensifies",
#       'location': {'x': 1236, 'y': 1153},
#       'size': {'height': 37, 'width': 340},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.7829546',
#         'index': 8,
#         'word': 'New',
#         'start': 30,
#         'end': 33},
#        {'entity': 'I-MISC',
#         'score': '0.9472659',
#         'index': 11,
#         'word': 's',
#         'start': 39,
#         'end': 40}],
#       'SA': {'pos': 0.7190999984741211, 'neg': 0.2808999717235565}}],
#     {'tag_name': 'div',
#      'text': 'Alex Brandon/AP',
#      'location': {'x': 1569, 'y': 1209},
#      'size': {'height': 11, 'width': 62},
#      'NER': [],
#      'SA': {}}]],
#   [{'tag_name': 'h3',
#     'text': 'Politics',
#     'location': {'x': 272, 'y': 1370},
#     'size': {'height': 15, 'width': 1360},
#     'NER': [],
#     'SA': {}},
#    [{'tag_name': 'span',
#      'text': 'Las Vegas memorial service for Harry Reid set for Jan. 8',
#      'location': {'x': 272, 'y': 1605},
#      'size': {'height': 42, 'width': 317},
#      'NER': [{'entity': 'B-LOC',
#        'score': '0.9991372',
#        'index': 1,
#        'word': 'Las',
#        'start': 0,
#        'end': 3},
#       {'entity': 'I-LOC',
#        'score': '0.99929476',
#        'index': 2,
#        'word': 'Vegas',
#        'start': 4,
#        'end': 9},
#       {'entity': 'B-PER',
#        'score': '0.9996232',
#        'index': 6,
#        'word': 'Harry',
#        'start': 31,
#        'end': 36},
#       {'entity': 'I-PER',
#        'score': '0.9995272',
#        'index': 7,
#        'word': 'Reid',
#        'start': 37,
#        'end': 41}],
#      'SA': {'pos': 0.7617918252944946, 'neg': 0.23820820450782776}},
#     {'tag_name': 'span',
#      'text': 'Biden, Putin hold call amid heightened tensions over Ukraine',
#      'location': {'x': 618, 'y': 1605},
#      'size': {'height': 42, 'width': 267},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.9991518',
#        'index': 1,
#        'word': 'B',
#        'start': 0,
#        'end': 1},
#       {'entity': 'B-PER',
#        'score': '0.94593334',
#        'index': 2,
#        'word': '##iden',
#        'start': 1,
#        'end': 5},
#       {'entity': 'B-PER',
#        'score': '0.99924266',
#        'index': 4,
#        'word': 'Putin',
#        'start': 7,
#        'end': 12},
#       {'entity': 'B-LOC',
#        'score': '0.9997681',
#        'index': 11,
#        'word': 'Ukraine',
#        'start': 53,
#        'end': 60}],
#      'SA': {'pos': 0.27827659249305725, 'neg': 0.7217233777046204}},
#     {'tag_name': 'span',
#      'text': "Biden administration asks Supreme Court to hear 'Remain in Mexico' case",
#      'location': {'x': 962, 'y': 1605},
#      'size': {'height': 42, 'width': 306},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.99736327',
#        'index': 1,
#        'word': 'B',
#        'start': 0,
#        'end': 1},
#       {'entity': 'B-PER',
#        'score': '0.930529',
#        'index': 2,
#        'word': '##iden',
#        'start': 1,
#        'end': 5},
#       {'entity': 'B-ORG',
#        'score': '0.9993635',
#        'index': 5,
#        'word': 'Supreme',
#        'start': 26,
#        'end': 33},
#       {'entity': 'I-ORG',
#        'score': '0.99862254',
#        'index': 6,
#        'word': 'Court',
#        'start': 34,
#        'end': 39},
#       {'entity': 'B-LOC',
#        'score': '0.999683',
#        'index': 14,
#        'word': 'Mexico',
#        'start': 59,
#        'end': 65}],
#      'SA': {'pos': 0.3461466431617737, 'neg': 0.6538533568382263}},
#     {'tag_name': 'span',
#      'text': "'Slow-motion insurrection': How GOP seizes election power",
#      'location': {'x': 1308, 'y': 1605},
#      'size': {'height': 42, 'width': 304},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.77844286',
#        'index': 12,
#        'word': 'GO',
#        'start': 32,
#        'end': 34},
#       {'entity': 'I-ORG',
#        'score': '0.75137043',
#        'index': 13,
#        'word': '##P',
#        'start': 34,
#        'end': 35}],
#      'SA': {'pos': 0.6525399088859558, 'neg': 0.3474600911140442}}]],
#   [[{'tag_name': 'h2',
#      'text': 'More News',
#      'location': {'x': 272, 'y': 1708},
#      'size': {'height': 15, 'width': 90},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'h2',
#       'text': 'Lawsuit seeks to block geothermal power plants',
#       'location': {'x': 272, 'y': 1748},
#       'size': {'height': 19, 'width': 314},
#       'NER': [],
#       'SA': {'pos': 0.07079650461673737, 'neg': 0.9292035698890686}},
#      {'tag_name': 'h2',
#       'text': 'Sewage spill closes south LA County beaches',
#       'location': {'x': 272, 'y': 1788},
#       'size': {'height': 19, 'width': 296},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.97894406',
#         'index': 7,
#         'word': 'LA',
#         'start': 26,
#         'end': 28},
#        {'entity': 'I-LOC',
#         'score': '0.99657476',
#         'index': 8,
#         'word': 'County',
#         'start': 29,
#         'end': 35}],
#       'SA': {'pos': 0.07068955153226852, 'neg': 0.9293105006217957}},
#      {'tag_name': 'h2',
#       'text': "New Year's Day Rose Parade set to go despite virus",
#       'location': {'x': 272, 'y': 1828},
#       'size': {'height': 19, 'width': 331},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.99150217',
#         'index': 1,
#         'word': 'New',
#         'start': 0,
#         'end': 3},
#        {'entity': 'I-MISC',
#         'score': '0.9739',
#         'index': 2,
#         'word': 'Year',
#         'start': 4,
#         'end': 8},
#        {'entity': 'I-MISC',
#         'score': '0.99099743',
#         'index': 3,
#         'word': "'",
#         'start': 8,
#         'end': 9},
#        {'entity': 'I-MISC',
#         'score': '0.99491704',
#         'index': 4,
#         'word': 's',
#         'start': 9,
#         'end': 10},
#        {'entity': 'I-MISC',
#         'score': '0.9961546',
#         'index': 5,
#         'word': 'Day',
#         'start': 11,
#         'end': 14},
#        {'entity': 'I-MISC',
#         'score': '0.85623264',
#         'index': 6,
#         'word': 'Rose',
#         'start': 15,
#         'end': 19},
#        {'entity': 'I-MISC',
#         'score': '0.99261075',
#         'index': 7,
#         'word': 'Parade',
#         'start': 20,
#         'end': 26}],
#       'SA': {'pos': 0.7736420631408691, 'neg': 0.22635789215564728}},
#      {'tag_name': 'h2',
#       'text': 'Germany shuts down half of nuclear plants',
#       'location': {'x': 272, 'y': 1868},
#       'size': {'height': 19, 'width': 286},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9998005',
#         'index': 1,
#         'word': 'Germany',
#         'start': 0,
#         'end': 7}],
#       'SA': {'pos': 0.08842774480581284, 'neg': 0.911572277545929}},
#      {'tag_name': 'h2',
#       'text': 'New infections driven by omicron soar in Australia',
#       'location': {'x': 272, 'y': 1908},
#       'size': {'height': 19, 'width': 334},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.99967396',
#         'index': 11,
#         'word': 'Australia',
#         'start': 41,
#         'end': 50}],
#       'SA': {'pos': 0.15631133317947388, 'neg': 0.8436886668205261}},
#      {'tag_name': 'h2',
#       'text': 'Postal Service recovers from poor 2020 holiday',
#       'location': {'x': 272, 'y': 1948},
#       'size': {'height': 19, 'width': 308},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.98312783',
#         'index': 1,
#         'word': 'Postal',
#         'start': 0,
#         'end': 6},
#        {'entity': 'I-ORG',
#         'score': '0.98176414',
#         'index': 2,
#         'word': 'Service',
#         'start': 7,
#         'end': 14}],
#       'SA': {'pos': 0.07011973857879639, 'neg': 0.9298802614212036}},
#      {'tag_name': 'h2',
#       'text': 'UN food agency halts work in N.Darfur, affects 2M',
#       'location': {'x': 272, 'y': 1988},
#       'size': {'height': 19, 'width': 330},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.9983998',
#         'index': 1,
#         'word': 'UN',
#         'start': 0,
#         'end': 2},
#        {'entity': 'B-LOC',
#         'score': '0.9954471',
#         'index': 8,
#         'word': 'N',
#         'start': 29,
#         'end': 30},
#        {'entity': 'I-LOC',
#         'score': '0.9694752',
#         'index': 9,
#         'word': '.',
#         'start': 30,
#         'end': 31},
#        {'entity': 'I-LOC',
#         'score': '0.99679345',
#         'index': 10,
#         'word': 'Dar',
#         'start': 31,
#         'end': 34},
#        {'entity': 'I-LOC',
#         'score': '0.99554235',
#         'index': 11,
#         'word': '##fu',
#         'start': 34,
#         'end': 36},
#        {'entity': 'I-LOC',
#         'score': '0.9987062',
#         'index': 12,
#         'word': '##r',
#         'start': 36,
#         'end': 37}],
#       'SA': {'pos': 0.03186796233057976, 'neg': 0.9681320786476135}},
#      {'tag_name': 'h2',
#       'text': 'Southern storms damage homes, buildings',
#       'location': {'x': 272, 'y': 2028},
#       'size': {'height': 19, 'width': 281},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.99963236',
#         'index': 1,
#         'word': 'Southern',
#         'start': 0,
#         'end': 8}],
#       'SA': {'pos': 0.1438879668712616, 'neg': 0.8561120629310608}},
#      {'tag_name': 'h2',
#       'text': 'More than 8,000 flights canceled this holiday week',
#       'location': {'x': 272, 'y': 2068},
#       'size': {'height': 19, 'width': 332},
#       'NER': [],
#       'SA': {'pos': 0.04360746964812279, 'neg': 0.9563925266265869}},
#      {'tag_name': 'h2',
#       'text': "What's next for Maxwell after guilty verdict?",
#       'location': {'x': 272, 'y': 2108},
#       'size': {'height': 19, 'width': 290},
#       'NER': [{'entity': 'B-PER',
#         'score': '0.9987159',
#         'index': 6,
#         'word': 'Maxwell',
#         'start': 16,
#         'end': 23}],
#       'SA': {'pos': 0.4499056041240692, 'neg': 0.5500944256782532}}]],
#    [{'tag_name': 'a',
#      'text': 'Progressives warn inaction on student debt could hurt Democrats in midterms',
#      'location': {'x': 752, 'y': 1978},
#      'size': {'height': 86, 'width': 395},
#      'NER': [{'entity': 'B-MISC',
#        'score': '0.99969375',
#        'index': 11,
#        'word': 'Democrats',
#        'start': 54,
#        'end': 63}],
#      'SA': {'pos': 0.21460767090320587, 'neg': 0.7853924036026001}},
#     {'tag_name': 'div',
#      'text': 'Dec 31',
#      'location': {'x': 752, 'y': 2073},
#      'size': {'height': 24, 'width': 400},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'a',
#       'text': "'A hell of a year': GOP eyes big 2022, but weaknesses remain",
#       'location': {'x': 775, 'y': 2117},
#       'size': {'height': 19, 'width': 352},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.9821145',
#         'index': 9,
#         'word': 'GO',
#         'start': 20,
#         'end': 22},
#        {'entity': 'I-ORG',
#         'score': '0.9782332',
#         'index': 10,
#         'word': '##P',
#         'start': 22,
#         'end': 23}],
#       'SA': {'pos': 0.20104004442691803, 'neg': 0.7989599704742432}},
#      {'tag_name': 'a',
#       'text': 'New laws take effect across US on abortion, policing, taxes',
#       'location': {'x': 775, 'y': 2147},
#       'size': {'height': 19, 'width': 340},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.99917895',
#         'index': 6,
#         'word': 'US',
#         'start': 28,
#         'end': 30}],
#       'SA': {'pos': 0.7225362062454224, 'neg': 0.27746373414993286}}],
#     {'tag_name': 'div',
#      'text': 'Anna Moneymaker/Getty Images',
#      'location': {'x': 1054, 'y': 2185},
#      'size': {'height': 11, 'width': 118},
#      'NER': [],
#      'SA': {}}]],
#   [[{'tag_name': 'a',
#      'text': "Zoo supports deputy's decision to shoot tiger after attack",
#      'location': {'x': 292, 'y': 2453},
#      'size': {'height': 59, 'width': 353},
#      'NER': [],
#      'SA': {'pos': 0.8385790586471558, 'neg': 0.16142095625400543}},
#     {'tag_name': 'div',
#      'text': 'Dec 31',
#      'location': {'x': 292, 'y': 2521},
#      'size': {'height': 24, 'width': 399},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'div',
#      'text': 'Landon Bost/Naples Daily News via USA Today',
#      'location': {'x': 543, 'y': 2554},
#      'size': {'height': 11, 'width': 168},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.9987821',
#        'index': 1,
#        'word': 'Landon',
#        'start': 0,
#        'end': 6},
#       {'entity': 'I-PER',
#        'score': '0.9984275',
#        'index': 2,
#        'word': 'Bo',
#        'start': 7,
#        'end': 9},
#       {'entity': 'B-ORG',
#        'score': '0.9991387',
#        'index': 5,
#        'word': 'Naples',
#        'start': 12,
#        'end': 18},
#       {'entity': 'I-ORG',
#        'score': '0.9991567',
#        'index': 6,
#        'word': 'Daily',
#        'start': 19,
#        'end': 24},
#       {'entity': 'I-ORG',
#        'score': '0.9990477',
#        'index': 7,
#        'word': 'News',
#        'start': 25,
#        'end': 29},
#       {'entity': 'B-ORG',
#        'score': '0.99361914',
#        'index': 9,
#        'word': 'USA',
#        'start': 34,
#        'end': 37},
#       {'entity': 'I-ORG',
#        'score': '0.996777',
#        'index': 10,
#        'word': 'Today',
#        'start': 38,
#        'end': 43}],
#      'SA': {'pos': 0.4452489912509918, 'neg': 0.5547509789466858}}],
#    [{'tag_name': 'a',
#      'text': 'Betty White, Harry Reid, John Madden and other notable people who died in 2021',
#      'location': {'x': 752, 'y': 2427},
#      'size': {'height': 86, 'width': 397},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.99937016',
#        'index': 1,
#        'word': 'Betty',
#        'start': 0,
#        'end': 5},
#       {'entity': 'I-PER',
#        'score': '0.99954635',
#        'index': 2,
#        'word': 'White',
#        'start': 6,
#        'end': 11},
#       {'entity': 'B-PER',
#        'score': '0.9997584',
#        'index': 4,
#        'word': 'Harry',
#        'start': 13,
#        'end': 18},
#       {'entity': 'I-PER',
#        'score': '0.9997002',
#        'index': 5,
#        'word': 'Reid',
#        'start': 19,
#        'end': 23},
#       {'entity': 'B-PER',
#        'score': '0.9997284',
#        'index': 7,
#        'word': 'John',
#        'start': 25,
#        'end': 29},
#       {'entity': 'I-PER',
#        'score': '0.9997217',
#        'index': 8,
#        'word': 'Mad',
#        'start': 30,
#        'end': 33},
#       {'entity': 'I-PER',
#        'score': '0.9978884',
#        'index': 9,
#        'word': '##den',
#        'start': 33,
#        'end': 36}],
#      'SA': {'pos': 0.42602619528770447, 'neg': 0.5739737749099731}},
#     {'tag_name': 'div',
#      'text': 'Dec 31',
#      'location': {'x': 752, 'y': 2522},
#      'size': {'height': 24, 'width': 400},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'div',
#      'text': 'Hulton Archive via Getty Images',
#      'location': {'x': 1056, 'y': 2555},
#      'size': {'height': 11, 'width': 116},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.99628866',
#        'index': 1,
#        'word': 'Hu',
#        'start': 0,
#        'end': 2},
#       {'entity': 'I-ORG',
#        'score': '0.9908538',
#        'index': 2,
#        'word': '##lton',
#        'start': 2,
#        'end': 6},
#       {'entity': 'I-ORG',
#        'score': '0.98909163',
#        'index': 3,
#        'word': 'Archive',
#        'start': 7,
#        'end': 14},
#       {'entity': 'B-ORG',
#        'score': '0.99918264',
#        'index': 5,
#        'word': 'Get',
#        'start': 19,
#        'end': 22},
#       {'entity': 'I-ORG',
#        'score': '0.99615794',
#        'index': 6,
#        'word': '##ty',
#        'start': 22,
#        'end': 24},
#       {'entity': 'I-ORG',
#        'score': '0.9990133',
#        'index': 7,
#        'word': 'Images',
#        'start': 25,
#        'end': 31}],
#      'SA': {'pos': 0.4277551472187042, 'neg': 0.5722448229789734}}]],
#   [{'tag_name': 'h2',
#     'text': '2021: Year in Review',
#     'location': {'x': 272, 'y': 2617},
#     'size': {'height': 15, 'width': 167},
#     'NER': [],
#     'SA': {}},
#    [[{'tag_name': 'div',
#       'text': '8:46',
#       'location': {'x': 284, 'y': 2804},
#       'size': {'height': 25, 'width': 44},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'span',
#       'text': 'The Year 2021: The biggest headlines of 2021',
#       'location': {'x': 272, 'y': 2857},
#       'size': {'height': 21, 'width': 308},
#       'NER': [],
#       'SA': {'pos': 0.8294938802719116, 'neg': 0.17050611972808838}}],
#     [{'tag_name': 'div',
#       'text': '4:59',
#       'location': {'x': 630, 'y': 2804},
#       'size': {'height': 25, 'width': 44},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'span',
#       'text': 'The Year 2021: Space exploration launches into new heights',
#       'location': {'x': 618, 'y': 2857},
#       'size': {'height': 42, 'width': 326},
#       'NER': [],
#       'SA': {'pos': 0.9107754230499268, 'neg': 0.08922454714775085}}],
#     [{'tag_name': 'div',
#       'text': '7:48',
#       'location': {'x': 974, 'y': 2804},
#       'size': {'height': 25, 'width': 44},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'span',
#       'text': 'The Year 2021: American heroes help inspire the country, move forward in 2021',
#       'location': {'x': 962, 'y': 2857},
#       'size': {'height': 42, 'width': 308},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.9994143',
#         'index': 6,
#         'word': 'American',
#         'start': 15,
#         'end': 23}],
#       'SA': {'pos': 0.9863440990447998, 'neg': 0.01365587767213583}}],
#     [{'tag_name': 'div',
#       'text': '7:44',
#       'location': {'x': 1320, 'y': 2804},
#       'size': {'height': 25, 'width': 44},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'span',
#       'text': 'The Year 2021: Remembering the lives lost in 2021',
#       'location': {'x': 1308, 'y': 2857},
#       'size': {'height': 42, 'width': 310},
#       'NER': [],
#       'SA': {'pos': 0.8426708579063416, 'neg': 0.15732909739017487}}]]],
#   [[{'tag_name': 'h2',
#      'text': 'More News',
#      'location': {'x': 272, 'y': 2960},
#      'size': {'height': 15, 'width': 90},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'h2',
#       'text': "'A moral giant': S.Africans pay respects to Tutu",
#       'location': {'x': 272, 'y': 3000},
#       'size': {'height': 19, 'width': 305},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.9983736',
#         'index': 7,
#         'word': 'S',
#         'start': 17,
#         'end': 18},
#        {'entity': 'I-MISC',
#         'score': '0.75310725',
#         'index': 8,
#         'word': '.',
#         'start': 18,
#         'end': 19},
#        {'entity': 'I-MISC',
#         'score': '0.9981481',
#         'index': 9,
#         'word': 'Africans',
#         'start': 19,
#         'end': 27},
#        {'entity': 'B-PER',
#         'score': '0.9988261',
#         'index': 13,
#         'word': 'Tu',
#         'start': 44,
#         'end': 46},
#        {'entity': 'B-PER',
#         'score': '0.7428232',
#         'index': 14,
#         'word': '##tu',
#         'start': 46,
#         'end': 48}],
#       'SA': {'pos': 0.943693220615387, 'neg': 0.05630679428577423}},
#      {'tag_name': 'h2',
#       'text': 'France urges green habits with bans on plastic',
#       'location': {'x': 272, 'y': 3040},
#       'size': {'height': 19, 'width': 305},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.99982387',
#         'index': 1,
#         'word': 'France',
#         'start': 0,
#         'end': 6}],
#       'SA': {'pos': 0.32517990469932556, 'neg': 0.6748201251029968}},
#      {'tag_name': 'h2',
#       'text': 'Tehran launches rocket into space: Iran state TV',
#       'location': {'x': 272, 'y': 3080},
#       'size': {'height': 19, 'width': 317},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9996643',
#         'index': 1,
#         'word': 'Tehran',
#         'start': 0,
#         'end': 6},
#        {'entity': 'B-ORG',
#         'score': '0.6093924',
#         'index': 7,
#         'word': 'Iran',
#         'start': 35,
#         'end': 39},
#        {'entity': 'B-ORG',
#         'score': '0.45251963',
#         'index': 9,
#         'word': 'TV',
#         'start': 46,
#         'end': 48}],
#       'SA': {'pos': 0.7002133727073669, 'neg': 0.29978659749031067}},
#      {'tag_name': 'h2',
#       'text': 'US unemployment claims drop to 198,000',
#       'location': {'x': 272, 'y': 3120},
#       'size': {'height': 19, 'width': 274},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9918618',
#         'index': 1,
#         'word': 'US',
#         'start': 0,
#         'end': 2}],
#       'SA': {'pos': 0.048775143921375275, 'neg': 0.9512248039245605}},
#      {'tag_name': 'h2',
#       'text': "Racism 'public health emergency': New York gov",
#       'location': {'x': 272, 'y': 3160},
#       'size': {'height': 19, 'width': 314},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9984842',
#         'index': 10,
#         'word': 'New',
#         'start': 34,
#         'end': 37},
#        {'entity': 'I-LOC',
#         'score': '0.9993562',
#         'index': 11,
#         'word': 'York',
#         'start': 38,
#         'end': 42}],
#       'SA': {'pos': 0.22297443449497223, 'neg': 0.777025580406189}},
#      {'tag_name': 'h2',
#       'text': "Officials promise groceries for Xi'an residents",
#       'location': {'x': 272, 'y': 3200},
#       'size': {'height': 19, 'width': 297},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.99749964',
#         'index': 9,
#         'word': 'Xi',
#         'start': 32,
#         'end': 34},
#        {'entity': 'I-LOC',
#         'score': '0.99421483',
#         'index': 10,
#         'word': "'",
#         'start': 34,
#         'end': 35},
#        {'entity': 'I-LOC',
#         'score': '0.98748267',
#         'index': 11,
#         'word': 'an',
#         'start': 35,
#         'end': 37}],
#       'SA': {'pos': 0.7223576307296753, 'neg': 0.27764227986335754}},
#      {'tag_name': 'h2',
#       'text': 'Satellite images show wreckage at Syria port',
#       'location': {'x': 272, 'y': 3240},
#       'size': {'height': 19, 'width': 291},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9998198',
#         'index': 6,
#         'word': 'Syria',
#         'start': 34,
#         'end': 39}],
#       'SA': {'pos': 0.09010220319032669, 'neg': 0.9098978042602539}},
#      {'tag_name': 'h2',
#       'text': 'Illinois police seek 2 in killing of 1 cop',
#       'location': {'x': 272, 'y': 3280},
#       'size': {'height': 19, 'width': 242},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9996704',
#         'index': 1,
#         'word': 'Illinois',
#         'start': 0,
#         'end': 8}],
#       'SA': {'pos': 0.17991942167282104, 'neg': 0.8200805187225342}},
#      {'tag_name': 'h2',
#       'text': 'UK officials prepare for hospital omicron surge',
#       'location': {'x': 272, 'y': 3320},
#       'size': {'height': 19, 'width': 308},
#       'NER': [{'entity': 'B-LOC',
#         'score': '0.9996511',
#         'index': 1,
#         'word': 'UK',
#         'start': 0,
#         'end': 2}],
#       'SA': {'pos': 0.2799365520477295, 'neg': 0.7200634479522705}},
#      {'tag_name': 'h2',
#       'text': "Popcorn, candy ban hits French cinemas' virus plan",
#       'location': {'x': 272, 'y': 3360},
#       'size': {'height': 19, 'width': 339},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.99974996',
#         'index': 7,
#         'word': 'French',
#         'start': 24,
#         'end': 30}],
#       'SA': {'pos': 0.4554612636566162, 'neg': 0.5445387363433838}}]],
#    [{'tag_name': 'a',
#      'text': 'The Year in Pictures: 2021',
#      'location': {'x': 752, 'y': 3269},
#      'size': {'height': 48, 'width': 414},
#      'NER': [],
#      'SA': {'pos': 0.5033506155014038, 'neg': 0.4966494143009186}},
#     {'tag_name': 'div',
#      'text': 'Dec 31',
#      'location': {'x': 752, 'y': 3322},
#      'size': {'height': 24, 'width': 860},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'a',
#       'text': 'Covid Christmas, winter weather, more celebrations: This Week in Pictures',
#       'location': {'x': 775, 'y': 3366},
#       'size': {'height': 19, 'width': 430},
#       'NER': [{'entity': 'B-MISC',
#         'score': '0.92644495',
#         'index': 1,
#         'word': 'Co',
#         'start': 0,
#         'end': 2},
#        {'entity': 'B-MISC',
#         'score': '0.98798174',
#         'index': 11,
#         'word': 'This',
#         'start': 52,
#         'end': 56},
#        {'entity': 'I-MISC',
#         'score': '0.99425477',
#         'index': 12,
#         'word': 'Week',
#         'start': 57,
#         'end': 61},
#        {'entity': 'I-MISC',
#         'score': '0.98830926',
#         'index': 14,
#         'word': 'Pictures',
#         'start': 65,
#         'end': 73}],
#       'SA': {'pos': 0.8497770428657532, 'neg': 0.15022292733192444}},
#      {'tag_name': 'a',
#       'text': '10 most memorable moments in sports in 2021',
#       'location': {'x': 775, 'y': 3396},
#       'size': {'height': 19, 'width': 275},
#       'NER': [],
#       'SA': {'pos': 0.9507531523704529, 'neg': 0.049246832728385925}}],
#     {'tag_name': 'div',
#      'text': 'Radchadawan Peungprasopporn/Facebook via AFP via Getty Images',
#      'location': {'x': 1390, 'y': 3434},
#      'size': {'height': 11, 'width': 242},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.8743682',
#        'index': 1,
#        'word': 'Ra',
#        'start': 0,
#        'end': 2},
#       {'entity': 'I-ORG',
#        'score': '0.50236636',
#        'index': 2,
#        'word': '##d',
#        'start': 2,
#        'end': 3},
#       {'entity': 'I-ORG',
#        'score': '0.9583249',
#        'index': 3,
#        'word': '##cha',
#        'start': 3,
#        'end': 6},
#       {'entity': 'I-ORG',
#        'score': '0.945084',
#        'index': 4,
#        'word': '##da',
#        'start': 6,
#        'end': 8},
#       {'entity': 'I-ORG',
#        'score': '0.97369415',
#        'index': 5,
#        'word': '##wan',
#        'start': 8,
#        'end': 11},
#       {'entity': 'I-ORG',
#        'score': '0.8836492',
#        'index': 6,
#        'word': 'P',
#        'start': 12,
#        'end': 13},
#       {'entity': 'I-ORG',
#        'score': '0.65463334',
#        'index': 7,
#        'word': '##eu',
#        'start': 13,
#        'end': 15},
#       {'entity': 'I-ORG',
#        'score': '0.63500214',
#        'index': 8,
#        'word': '##ng',
#        'start': 15,
#        'end': 17},
#       {'entity': 'I-ORG',
#        'score': '0.5584443',
#        'index': 9,
#        'word': '##pra',
#        'start': 17,
#        'end': 20},
#       {'entity': 'B-ORG',
#        'score': '0.5588266',
#        'index': 14,
#        'word': 'Facebook',
#        'start': 28,
#        'end': 36},
#       {'entity': 'B-ORG',
#        'score': '0.9992176',
#        'index': 16,
#        'word': 'A',
#        'start': 41,
#        'end': 42},
#       {'entity': 'I-ORG',
#        'score': '0.99656564',
#        'index': 17,
#        'word': '##FP',
#        'start': 42,
#        'end': 44},
#       {'entity': 'B-ORG',
#        'score': '0.9988482',
#        'index': 19,
#        'word': 'Get',
#        'start': 49,
#        'end': 52},
#       {'entity': 'I-ORG',
#        'score': '0.99369013',
#        'index': 20,
#        'word': '##ty',
#        'start': 52,
#        'end': 54},
#       {'entity': 'I-ORG',
#        'score': '0.99899584',
#        'index': 21,
#        'word': 'Images',
#        'start': 55,
#        'end': 61}],
#      'SA': {'pos': 0.41579967737197876, 'neg': 0.5842003226280212}}]],
#   [[{'tag_name': 'a',
# ...
#        'index': 13,
#        'word': '##ty',
#        'start': 26,
#        'end': 28},
#       {'entity': 'I-ORG',
#        'score': '0.999057',
#        'index': 14,
#        'word': 'Images',
#        'start': 29,
#        'end': 35}],
#      'SA': {'pos': 0.32113707065582275, 'neg': 0.6788629293441772}}],
#    [{'tag_name': 'a',
#      'text': 'SLIDESHOW: Betty White through the years',
#      'location': {'x': 752, 'y': 7362},
#      'size': {'height': 59, 'width': 395},
#      'NER': [{'entity': 'B-PER',
#        'score': '0.9988714',
#        'index': 7,
#        'word': 'Betty',
#        'start': 11,
#        'end': 16},
#       {'entity': 'I-PER',
#        'score': '0.98975986',
#        'index': 8,
#        'word': 'White',
#        'start': 17,
#        'end': 22}],
#      'SA': {'pos': 0.9476006031036377, 'neg': 0.05239936709403992}},
#     {'tag_name': 'div',
#      'text': '1 hour ago',
#      'location': {'x': 752, 'y': 7430},
#      'size': {'height': 24, 'width': 400},
#      'NER': [],
#      'SA': {}},
#     [{'tag_name': 'a',
#       'text': 'Betty White, Harry Reid, John Madden and other notable people who died in 2021',
#       'location': {'x': 775, 'y': 7474},
#       'size': {'height': 37, 'width': 374},
#       'NER': [{'entity': 'B-PER',
#         'score': '0.99937016',
#         'index': 1,
#         'word': 'Betty',
#         'start': 0,
#         'end': 5},
#        {'entity': 'I-PER',
#         'score': '0.99954635',
#         'index': 2,
#         'word': 'White',
#         'start': 6,
#         'end': 11},
#        {'entity': 'B-PER',
#         'score': '0.9997584',
#         'index': 4,
#         'word': 'Harry',
#         'start': 13,
#         'end': 18},
#        {'entity': 'I-PER',
#         'score': '0.9997002',
#         'index': 5,
#         'word': 'Reid',
#         'start': 19,
#         'end': 23},
#        {'entity': 'B-PER',
#         'score': '0.9997284',
#         'index': 7,
#         'word': 'John',
#         'start': 25,
#         'end': 29},
#        {'entity': 'I-PER',
#         'score': '0.9997217',
#         'index': 8,
#         'word': 'Mad',
#         'start': 30,
#         'end': 33},
#        {'entity': 'I-PER',
#         'score': '0.9978884',
#         'index': 9,
#         'word': '##den',
#         'start': 33,
#         'end': 36}],
#       'SA': {'pos': 0.42602619528770447, 'neg': 0.5739737749099731}},
#      {'tag_name': 'a',
#       'text': 'The Life and Times of Desmond Tutu',
#       'location': {'x': 775, 'y': 7522},
#       'size': {'height': 19, 'width': 212},
#       'NER': [{'entity': 'I-ORG',
#         'score': '0.9914102',
#         'index': 3,
#         'word': 'and',
#         'start': 9,
#         'end': 12},
#        {'entity': 'I-ORG',
#         'score': '0.84479845',
#         'index': 4,
#         'word': 'Times',
#         'start': 13,
#         'end': 18},
#        {'entity': 'I-MISC',
#         'score': '0.5240846',
#         'index': 5,
#         'word': 'of',
#         'start': 19,
#         'end': 21},
#        {'entity': 'B-PER',
#         'score': '0.99761117',
#         'index': 6,
#         'word': 'Desmond',
#         'start': 22,
#         'end': 29},
#        {'entity': 'I-PER',
#         'score': '0.9986167',
#         'index': 7,
#         'word': 'Tu',
#         'start': 30,
#         'end': 32},
#        {'entity': 'I-PER',
#         'score': '0.98446494',
#         'index': 8,
#         'word': '##tu',
#         'start': 32,
#         'end': 34}],
#       'SA': {'pos': 0.9480807185173035, 'neg': 0.05191928148269653}}],
#     {'tag_name': 'div',
#      'text': 'ABC via Getty Images',
#      'location': {'x': 1092, 'y': 7560},
#      'size': {'height': 11, 'width': 80},
#      'NER': [],
#      'SA': {}}]],
#   [[{'tag_name': 'span',
#      'text': 'ABC NEWS',
#      'location': {'x': 272, 'y': 7714},
#      'size': {'height': 0, 'width': 0},
#      'NER': [],
#      'SA': {}},
#     {'tag_name': 'h4',
#      'text': 'BACK TO TOP',
#      'location': {'x': 1554, 'y': 7676},
#      'size': {'height': 21, 'width': 78},
#      'NER': [],
#      'SA': {}}],
#    [[{'tag_name': 'h2',
#       'text': 'SECTIONS',
#       'location': {'x': 272, 'y': 7746},
#       'size': {'height': 33, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'U.S.',
#       'location': {'x': 272, 'y': 7779},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'International',
#       'location': {'x': 272, 'y': 7808},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Politics',
#       'location': {'x': 272, 'y': 7838},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Health',
#       'location': {'x': 272, 'y': 7868},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Entertainment',
#       'location': {'x': 272, 'y': 7898},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Sports',
#       'location': {'x': 272, 'y': 7928},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Money',
#       'location': {'x': 272, 'y': 7957},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Technology',
#       'location': {'x': 272, 'y': 7987},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Travel',
#       'location': {'x': 272, 'y': 8017},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Recipes',
#       'location': {'x': 272, 'y': 8047},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}}],
#     [{'tag_name': 'h2',
#       'text': 'SHOWS',
#       'location': {'x': 612, 'y': 7746},
#       'size': {'height': 33, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Good Morning America',
#       'location': {'x': 612, 'y': 7779},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'World News Tonight with David Muir',
#       'location': {'x': 612, 'y': 7808},
#       'size': {'height': 17, 'width': 330},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.9138197',
#         'index': 1,
#         'word': 'World',
#         'start': 0,
#         'end': 5},
#        {'entity': 'I-ORG',
#         'score': '0.5337858',
#         'index': 2,
#         'word': 'News',
#         'start': 6,
#         'end': 10},
#        {'entity': 'I-ORG',
#         'score': '0.6165476',
#         'index': 3,
#         'word': 'Tonight',
#         'start': 11,
#         'end': 18},
#        {'entity': 'B-PER',
#         'score': '0.99965477',
#         'index': 5,
#         'word': 'David',
#         'start': 24,
#         'end': 29},
#        {'entity': 'I-PER',
#         'score': '0.9996842',
#         'index': 6,
#         'word': 'Muir',
#         'start': 30,
#         'end': 34}],
#       'SA': {'pos': 0.7056105732917786, 'neg': 0.29438942670822144}},
#      {'tag_name': 'h4',
#       'text': 'Nightline',
#       'location': {'x': 612, 'y': 7838},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'World News Now & America This Morning',
#       'location': {'x': 612, 'y': 7868},
#       'size': {'height': 17, 'width': 330},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.9881534',
#         'index': 1,
#         'word': 'World',
#         'start': 0,
#         'end': 5},
#        {'entity': 'I-ORG',
#         'score': '0.91048896',
#         'index': 2,
#         'word': 'News',
#         'start': 6,
#         'end': 10},
#        {'entity': 'I-ORG',
#         'score': '0.9583932',
#         'index': 3,
#         'word': 'Now',
#         'start': 11,
#         'end': 14},
#        {'entity': 'I-ORG',
#         'score': '0.8087467',
#         'index': 4,
#         'word': '&',
#         'start': 15,
#         'end': 16},
#        {'entity': 'I-MISC',
#         'score': '0.67953634',
#         'index': 5,
#         'word': 'America',
#         'start': 17,
#         'end': 24},
#        {'entity': 'I-ORG',
#         'score': '0.69849783',
#         'index': 6,
#         'word': 'This',
#         'start': 25,
#         'end': 29},
#        {'entity': 'I-MISC',
#         'score': '0.51349074',
#         'index': 7,
#         'word': 'Morning',
#         'start': 30,
#         'end': 37}],
#       'SA': {'pos': 0.6658134460449219, 'neg': 0.3341865837574005}},
#      {'tag_name': 'h4',
#       'text': 'This Week with George Stephanopoulos',
#       'location': {'x': 612, 'y': 7898},
#       'size': {'height': 17, 'width': 330},
#       'NER': [{'entity': 'I-MISC',
#         'score': '0.71737593',
#         'index': 2,
#         'word': 'Week',
#         'start': 5,
#         'end': 9},
#        {'entity': 'B-PER',
#         'score': '0.9997379',
#         'index': 4,
#         'word': 'George',
#         'start': 15,
#         'end': 21},
#        {'entity': 'I-PER',
#         'score': '0.9997389',
#         'index': 5,
#         'word': 'Stephan',
#         'start': 22,
#         'end': 29},
#        {'entity': 'I-PER',
#         'score': '0.99916995',
#         'index': 6,
#         'word': '##op',
#         'start': 29,
#         'end': 31},
#        {'entity': 'I-PER',
#         'score': '0.89506954',
#         'index': 7,
#         'word': '##ou',
#         'start': 31,
#         'end': 33},
#        {'entity': 'I-PER',
#         'score': '0.87176585',
#         'index': 8,
#         'word': '##los',
#         'start': 33,
#         'end': 36}],
#       'SA': {'pos': 0.5262327790260315, 'neg': 0.4737672805786133}},
#      {'tag_name': 'h4',
#       'text': '20/20',
#       'location': {'x': 612, 'y': 7928},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'What Would You Do?',
#       'location': {'x': 612, 'y': 7957},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'ABC.com',
#       'location': {'x': 612, 'y': 7987},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}}],
#     [{'tag_name': 'h2',
#       'text': 'TOOLS',
#       'location': {'x': 952, 'y': 7746},
#       'size': {'height': 33, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Devices',
#       'location': {'x': 952, 'y': 7779},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Facebook',
#       'location': {'x': 952, 'y': 7808},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Twitter',
#       'location': {'x': 952, 'y': 7838},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'YouTube',
#       'location': {'x': 952, 'y': 7868},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Press Releases',
#       'location': {'x': 952, 'y': 7898},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Site Map',
#       'location': {'x': 952, 'y': 7928},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}}],
#     [{'tag_name': 'h2',
#       'text': 'ABOUT',
#       'location': {'x': 1292, 'y': 7746},
#       'size': {'height': 33, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Contact Us',
#       'location': {'x': 1292, 'y': 7779},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Feedback',
#       'location': {'x': 1292, 'y': 7808},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Share Tips with ABC News',
#       'location': {'x': 1292, 'y': 7838},
#       'size': {'height': 17, 'width': 330},
#       'NER': [{'entity': 'B-ORG',
#         'score': '0.99902797',
#         'index': 7,
#         'word': 'ABC',
#         'start': 16,
#         'end': 19},
#        {'entity': 'I-ORG',
#         'score': '0.998357',
#         'index': 8,
#         'word': 'News',
#         'start': 20,
#         'end': 24}],
#       'SA': {'pos': 0.6763811111450195, 'neg': 0.3236188590526581}},
#      {'tag_name': 'h4',
#       'text': 'Terms of Use',
#       'location': {'x': 1292, 'y': 7868},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Privacy Policy',
#       'location': {'x': 1292, 'y': 7898},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Do Not Sell My Info',
#       'location': {'x': 1292, 'y': 7928},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {'pos': 0.7808289527893066, 'neg': 0.21917107701301575}},
#      {'tag_name': 'h4',
#       'text': 'Your California Privacy Rights',
#       'location': {'x': 1292, 'y': 7957},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': "Children's Online Privacy Policy",
#       'location': {'x': 1292, 'y': 7987},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Interest-Based Ads',
#       'location': {'x': 1292, 'y': 8017},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Advertise with Us',
#       'location': {'x': 1292, 'y': 8047},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'About Nielsen Measurement',
#       'location': {'x': 1292, 'y': 8077},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'ABC News Store',
#       'location': {'x': 1292, 'y': 8106},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Authors List',
#       'location': {'x': 1292, 'y': 8136},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {}},
#      {'tag_name': 'h4',
#       'text': 'Image/Video Solicitation Rights Confirmation Terms',
#       'location': {'x': 1292, 'y': 8166},
#       'size': {'height': 17, 'width': 330},
#       'NER': [],
#       'SA': {'pos': 0.14454279839992523, 'neg': 0.8554571866989136}}]],
#    [{'tag_name': 'span',
#      'text': 'External links are provided for reference purposes. ABC News is not responsible for the content of external Internet sites.',
#      'location': {'x': 272, 'y': 8197},
#      'size': {'height': 21, 'width': 680},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.9992466',
#        'index': 9,
#        'word': 'ABC',
#        'start': 52,
#        'end': 55},
#       {'entity': 'I-ORG',
#        'score': '0.9986118',
#        'index': 10,
#        'word': 'News',
#        'start': 56,
#        'end': 60},
#       {'entity': 'B-MISC',
#        'score': '0.99746287',
#        'index': 19,
#        'word': 'Internet',
#        'start': 108,
#        'end': 116}],
#      'SA': {'pos': 0.06347262859344482, 'neg': 0.9365274310112}},
#     {'tag_name': 'span',
#      'text': 'Copyright © 2022 ABC News Internet Ventures. All rights reserved.',
#      'location': {'x': 1288, 'y': 8197},
#      'size': {'height': 21, 'width': 344},
#      'NER': [{'entity': 'B-ORG',
#        'score': '0.9990601',
#        'index': 5,
#        'word': 'ABC',
#        'start': 17,
#        'end': 20},
#       {'entity': 'I-ORG',
#        'score': '0.9988335',
#        'index': 6,
#        'word': 'News',
#        'start': 21,
#        'end': 25},
#       {'entity': 'I-ORG',
#        'score': '0.9990048',
#        'index': 7,
#        'word': 'Internet',
#        'start': 26,
#        'end': 34},
#       {'entity': 'I-ORG',
#        'score': '0.99816775',
#        'index': 8,
#        'word': 'Ventures',
#        'start': 35,
#        'end': 43}],
#      'SA': {'pos': 0.14423951506614685, 'neg': 0.8557605147361755}}]]],
#  'ABC-News-(Online)',
#  '20220101000143']

# %%
# class represent a html element
class html_element:
    def __init__(self, json_ele, media_name, date, leaning = None):
        # x, y, width, height, children = list, dict or None
        self.media_name = media_name
        self.date = date
        if leaning is None:
            self.leaning = get_bias_leaning(self.media_name)
        else:
            self.leaning = leaning
        
        # if no children, tag, text and attr variable are avilable
        self.__construct_children(json_ele)
        self.__construct_cord(json_ele)
        self.__construct_size(json_ele)
        
    def __construct_children(self, json_ele):
        if isinstance(json_ele, dict):
            # no children
            self.children = None
            self.attr = {}
            # also construct tag and text
            for k,v in json_ele.items():
                self.attr[k] = v
        else:
            self.children = []
            for x in json_ele:
                self.children.append(html_element(json_ele = x, media_name = self.media_name, date = self.date, \
                                                 leaning = self.leaning))
            
    def __construct_cord(self, json_ele):
        if isinstance(json_ele, dict):
            # no children
            self.x = json_ele["location"]["x"]
            self.y = json_ele["location"]["y"]
        else:
            children_x = [child.x for child in self.children]
            children_y = [child.y for child in self.children]
            
            # cords of a nested element are the smallest x and y (topleft corner)
            try:
                self.x = min(children_x)
                self.y = min(children_y)
            except Exception as e:
                print(children_x)
                print(children_y)
                raise e
            
    def __construct_size(self, json_ele):
        if isinstance(json_ele, dict):
            # no children
            self.width = json_ele["size"]["width"]
            self.height = json_ele["size"]["height"]
        else:
            right_bound = [child.width + child.x for child in self.children]
            bottom_bound = [child.height + child.y for child in self.children]
            
            # size of a nested element are from topleft corner to bottomright corner
            self.width = max(right_bound) - self.x
            self.height = max(bottom_bound) - self.y
        
    def __eq__(self, other):
        # may need a more robust matching strategy
        # may need to include class attribute
        if isinstance(other, type(self)) and isinstance(self.children, type(other.children)):
            if isinstance(self.children, list):
                # is nested element  
                return self.children == other.children
            else:
                return self.text == other.text and self.tag == other.tag
        else:
            return False
    
    def get_json_repr(self):
        # return a list or dict
        if self.children:
            return [x.get_json_repr() for x in self.children]
        else:
            return {'tag_name': self.tag,
                'text': self.text,
                'location': {'x': self.x, 'y': self.y},
                'size': {'height': self.height, 'width': self.width}}

# %%
def processing_element(html_element):
    result = []
    
    if html_element.children:
        for x in html_element.children:
            result +=  processing_element(x)
    else:
        element = {}
        
        # x, y and size
        element["x"] = html_element.attr["location"]["x"]
        element["y"] = html_element.attr["location"]["y"]
        element["height"] = html_element.attr["size"]["height"]
        element["width"] = html_element.attr["size"]["width"]
        element["NER"] = html_element.attr["NER"]
        element["SA"] = html_element.attr["SA"]
        
        element["tag"] = html_element.attr["tag_name"]
        element["text"] = html_element.attr["text"]
        
        element["name"] = html_element.media_name
        element["date"] = html_element.date
        element["leaning"] = html_element.leaning
        
        result.append(element)
    
    return result

# %%
d1 = html_element(*read_json("../data/sites_jsons/json/ABC-News-(Online)_20220101000143.json"))

e_sizes = processing_element(d1)
e_sizes[0]
# Out:
# {'x': 272,
#  'y': 7233,
#  'height': 0,
#  'width': 0,
#  'NER': [],
#  'SA': {},
#  'tag': 'span',
#  'text': 'ABC News',
#  'name': 'ABC-News-(Online)',
#  'date': '20220101000143',
#  'leaning': 'Lean Left'}

# %% [markdown]
# # create parquet

# %%
import os
import concurrent
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
import time

# %%
def size_worker(file_name):
    path = os.path.join(dir_path, file_name)
    e = html_element(*read_json(path))
    return processing_element(e)


dir_path = "../data/sites_jsons/json"
e_sizes = []
count = 0

with ProcessPoolExecutor(max_workers=6) as executor:
    future_to_file = {executor.submit(size_worker, file_name): file_name for file_name in os.listdir(dir_path)}

    for future in concurrent.futures.as_completed(future_to_file):
        result = future.result()
        count += len(result)
        e_sizes += result

e_sizes = pd.DataFrame(e_sizes)

# %%
e_sizes.to_parquet('./processed_data/raw_data.pkl')

# %%
e_sizes
# Out:
#             x      y  height  width NER  \
# 0           8     13      15   1904  []
# 1           0   9051       9     78  []
# 2         511   9090      23     71  []
# 3         646   9090      23     91  []
# 4         801   9090      23     95  []
# ...       ...    ...     ...    ...  ..
# 1725607   912  10219      13     80  []
# 1725608   998  10219      13     70  []
# 1725609  1074  10219      13    147  []
# 1725610  1248  10219      13    183  []
# 1725611     0  10272      18   1905  []
#
#                                                         SA     tag  \
# 0        {'pos': 0.12073664367198944, 'neg': 0.87926328...     pre
# 1                                                       {}       a
# 2                                                       {}  button
# 3                                                       {}  button
# 4                                                       {}  button
# ...                                                    ...     ...
# 1725607                                                 {}       a
# 1725608                                                 {}       a
# 1725609                                                 {}       a
# 1725610  {'pos': 0.7204211950302124, 'neg': 0.279578834...       a
# 1725611  {'pos': 0.17875263094902039, 'neg': 0.82124733...     div
#
#                                                       text              name  \
# 0                             Could not establish a tunnel  Associated-Press
# 1                                     Skip to main content             Axios
# 2                                                 Sections             Axios
# 3                                               Local news             Axios
# 4                                              About Axios             Axios
# ...                                                    ...               ...
# 1725607                                   Terms of Service     Time-Magazine
# 1725608                                     Privacy Policy     Time-Magazine
# 1725609                     Your California Privacy Rights     Time-Magazine
# 1725610                Do Not Sell My Personal Information     Time-Magazine
# 1725611  Could not connect to the reCAPTCHA service. Pl...     Time-Magazine
#
#                    date    leaning
# 0        20220101004109  Lean Left
# 1        20220101001505  Lean Left
# 2        20220101001505  Lean Left
# 3        20220101001505  Lean Left
# 4        20220101001505  Lean Left
# ...                 ...        ...
# 1725607  20220301204820  Lean Left
# 1725608  20220301204820  Lean Left
# 1725609  20220301204820  Lean Left
# 1725610  20220301204820  Lean Left
# 1725611  20220301204820  Lean Left
#
# [1725612 rows x 11 columns]

# %%
pd.set_option('display.max_colwidth', None)
e_sizes[e_sizes["text"] == "Exclusive Book: How the Specter of Communism Is Ruling Our World"]
# Out:
#             x     y  height  width  \
# 8147     1252  4410      40    300
# 1332067  1252  8043      40    300
# 1334325  1252  3873      40    300
# 1335227     8  7824      18   1889
# 1336879     8  7759      18   1889
# ...       ...   ...     ...    ...
# 1672335     8  7774      18   1889
# 1672950     8  7351      18   1889
# 1673501  1252  3854      40    188
# 1674220     8  7351      18   1889
# 1675203  1252  3869      40    188
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          NER  \
# 8147     [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1332067  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1334325  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1335227  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1336879  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 1672335  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1672950  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1673501  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1674220  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
# 1675203  [{'entity': 'B-PER', 'score': '0.8569692', 'index': 7, 'word': 'S', 'start': 24, 'end': 25}, {'entity': 'I-PER', 'score': '0.3834895', 'index': 8, 'word': '##pect', 'start': 25, 'end': 29}, {'entity': 'B-MISC', 'score': '0.6980022', 'index': 11, 'word': 'Co', 'start': 35, 'end': 37}, {'entity': 'I-MISC', 'score': '0.87380266', 'index': 12, 'word': '##mm', 'start': 37, 'end': 39}, {'entity': 'I-MISC', 'score': '0.8429744', 'index': 13, 'word': '##uni', 'start': 39, 'end': 42}, {'entity': 'I-MISC', 'score': '0.9559942', 'index': 14, 'word': '##sm', 'start': 42, 'end': 44}, {'entity': 'I-MISC', 'score': '0.9219736', 'index': 20, 'word': 'World', 'start': 59, 'end': 64}]
#
#                                                              SA  tag  \
# 8147     {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1332067  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1334325  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1335227  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1336879  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# ...                                                         ...  ...
# 1672335  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1672950  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1673501  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1674220  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
# 1675203  {'pos': 0.8878241181373596, 'neg': 0.1121758371591568}  div
#
#                                                                      text  \
# 8147     Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1332067  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1334325  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1335227  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1336879  Exclusive Book: How the Specter of Communism Is Ruling Our World
# ...                                                                   ...
# 1672335  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1672950  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1673501  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1674220  Exclusive Book: How the Specter of Communism Is Ruling Our World
# 1675203  Exclusive Book: How the Specter of Communism Is Ruling Our World
#
#                     name            date     leaning
# 8147     The-Epoch-Times  20220101005134  Lean Right
# 1332067  The-Epoch-Times  20220102105136  Lean Right
# 1334325  The-Epoch-Times  20220106105134  Lean Right
# 1335227  The-Epoch-Times  20220104104449  Lean Right
# 1336879  The-Epoch-Times  20220108205143  Lean Right
# ...                  ...             ...         ...
# 1672335  The-Epoch-Times  20220314160646  Lean Right
# 1672950  The-Epoch-Times  20220310064704  Lean Right
# 1673501  The-Epoch-Times  20220324163438  Lean Right
# 1674220  The-Epoch-Times  20220326163251  Lean Right
# 1675203  The-Epoch-Times  20220329164802  Lean Right
#
# [123 rows x 11 columns]

# %% [markdown]
# # filter text length

# %%
# drop words:

df_one = df_frontpage[[len(x) <= 19 for x in df_frontpage["text"]]]
# df_one = df_one[df_one["word"].notna()]
df_one

# %%
# drop words:

df_one = df_frontpage[[len(x) <= 19 for x in df_frontpage["text"]]]
# df_one = df_one[df_one["word"].notna()]
df_one

# %%
import matplotlib.pyplot as plt

# Unzipping the list of tuples
x, y = zip(*percentages)

# Creating the plot
plt.plot(x, y, marker='o')  # You can change the marker style if you wish
plt.xlabel('length of text (characters)')  # Customize with your label
plt.ylabel('percentage with at lest one NER')  # Customize with your label
plt.title('length of text vs percentage with NER')  # Customize with your title

# Display the plot
plt.show()

# %%
cal_perc(df_frontpage, 20)

# %%
df_frontpage = df_frontpage[[len(x) > 19 for x in df_frontpage["text"]]]
df_frontpage.sample(10)

# %% [markdown]
# # Merge tokens

# %%
# filter out short text

# %%
# merge may be too agressive

# %%
import seaborn as sns    
import pandas as pd
import json
import copy
import regex as re

import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
# load pickel 
e_sizes = pd.read_pickle('elements_stats.pkl')
e_sizes['text'] = e_sizes['text'].str.strip()

# ensure the e is not too small or invisible
e_sizes = e_sizes.loc[(e_sizes["width"] > 15) & (e_sizes["height"] > 15) & e_sizes["text"]]

# %%
# remove some tags
to_remove = ["button", "label", "date", "time", "u", "legend", "pre", "nav-search-bucket", "media-badge", "lit-timestamp"]
e_sizes = e_sizes[~e_sizes['tag'].isin(to_remove)]

# %%
e_sizes
# Out:
#             x      y  height  width  \
# 6         272    167      19    325
# 7         272    207      19    324
# 8         272    247      19    297
# 9         272    287      19    309
# 10        272    327      19    263
# ...       ...    ...     ...    ...
# 1725571   338   9594      71    285
# 1725572   653   9594      47    285
# 1725573   967   9594      71    285
# 1725574  1281   9594      47    285
# 1725611     0  10272      18   1905
#
#                                                        NER  \
# 6        [{'entity': 'B-PER', 'score': '0.9978671', 'in...
# 7                                                       []
# 8                                                       []
# 9        [{'entity': 'B-ORG', 'score': '0.9989704', 'in...
# 10                                                      []
# ...                                                    ...
# 1725571  [{'entity': 'B-ORG', 'score': '0.9852402', 'in...
# 1725572  [{'entity': 'B-LOC', 'score': '0.99959725', 'i...
# 1725573  [{'entity': 'B-LOC', 'score': '0.999783', 'ind...
# 1725574  [{'entity': 'B-ORG', 'score': '0.9946989', 'in...
# 1725611                                                 []
#
#                                                         SA  tag  \
# 6        {'pos': 0.1687677949666977, 'neg': 0.831232190...   h2
# 7        {'pos': 0.13421954214572906, 'neg': 0.86578053...   h2
# 8        {'pos': 0.09297964721918106, 'neg': 0.90702039...   h2
# 9        {'pos': 0.1945149451494217, 'neg': 0.805485069...   h2
# 10       {'pos': 0.8186860680580139, 'neg': 0.181313917...   h2
# ...                                                    ...  ...
# 1725571  {'pos': 0.0774001032114029, 'neg': 0.922599911...   h3
# 1725572  {'pos': 0.8407050371170044, 'neg': 0.159294947...   h3
# 1725573  {'pos': 0.6308440566062927, 'neg': 0.369155913...   h3
# 1725574  {'pos': 0.512549102306366, 'neg': 0.4874509572...   h3
# 1725611  {'pos': 0.17875263094902039, 'neg': 0.82124733...  div
#
#                                                       text               name  \
# 6         Biden threaten Putin with sanctions over Ukraine  ABC-News-(Online)
# 7        Coaches made teen eat pizza despite religion: ...  ABC-News-(Online)
# 8          Suspect arrested in shooting of police officers  ABC-News-(Online)
# 9           DOJ drops case against cops in Epstein suicide  ABC-News-(Online)
# 10                Powerball jackpot raised to $500 million  ABC-News-(Online)
# ...                                                    ...                ...
# 1725571  Climate Change Will Mean More Expensive Grocer...      Time-Magazine
# 1725572  Iowa is the Front Line in a Battle Over Carbon...      Time-Magazine
# 1725573  Russia Tensions Could Push Europe to a Clean E...      Time-Magazine
# 1725574       The U.S. Military Might Never Be Sustainable      Time-Magazine
# 1725611  Could not connect to the reCAPTCHA service. Pl...      Time-Magazine
#
#                    date    leaning
# 6        20220101000143  Lean Left
# 7        20220101000143  Lean Left
# 8        20220101000143  Lean Left
# 9        20220101000143  Lean Left
# 10       20220101000143  Lean Left
# ...                 ...        ...
# 1725571  20220301204820  Lean Left
# 1725572  20220301204820  Lean Left
# 1725573  20220301204820  Lean Left
# 1725574  20220301204820  Lean Left
# 1725611  20220301204820  Lean Left
#
# [1311611 rows x 11 columns]

# %%
e_sizes.iloc[4]["text"]
# Out:
# 'Powerball jackpot raised to $500 million'

# %%
# NER post processing 

# 1. merge adjacent word
def merge_adjacent_ner(ner_list, text):
    ner_list = copy.deepcopy(ner_list)
    p = re.compile(r'[\s\\\p{P}]+$')

    new_ner_list = []
    if not ner_list:
        return new_ner_list
    else:
        new_ner_list.append(ner_list[0])
    
    for x in ner_list[1:]:
        # same entity and connected, then merge
        if x["entity"].startswith("I") or \
        (x["entity"] == new_ner_list[-1]["entity"] and all(char in [" ", "'"] for char in text[new_ner_list[-1]["end"] : x["start"]])):
            # merge I entity
#             if new_ner_list[-1]["end"] != x["start"]:
#                 print(text[new_ner_list[-1]["end"] : x["start"]])
            
            new_ner_list[-1]["score"] = new_ner_list[-1]["score"] if new_ner_list[-1]["score"] < x["score"] else x["score"]
            new_ner_list[-1]["word"] = text[new_ner_list[-1]["start"] : x["end"]]
            new_ner_list[-1]["end"] = x["end"]
        else:
            new_ner_list.append(x)
        
    for x in new_ner_list:
        if x["end"] < len(text) and text[x["end"]] != " ":
            # expand to include the whole word
            x["end"] = text.find(' ', x["end"])
            x["word"] = text[x["start"] : x["end"]]
        
        old_len = len(x["word"])
        x["word"] = p.sub('', x["word"])
        x["end"] -= old_len - len(x["word"])

    
    return new_ner_list

row = e_sizes.loc[38]
print(row["NER"])
print("******")
merge_adjacent_ner(row["NER"], row["text"])
# Out:
# [{'entity': 'B-PER', 'score': '0.87566996', 'index': 1, 'word': 'Con', 'start': 0, 'end': 3}, {'entity': 'I-MISC', 'score': '0.59498155', 'index': 2, 'word': '##fe', 'start': 3, 'end': 5}, {'entity': 'B-MISC', 'score': '0.9719853', 'index': 7, 'word': 'New', 'start': 25, 'end': 28}, {'entity': 'I-MISC', 'score': '0.842094', 'index': 8, 'word': 'Year', 'start': 29, 'end': 33}, {'entity': 'I-MISC', 'score': '0.6991049', 'index': 9, 'word': "'", 'start': 33, 'end': 34}, {'entity': 'I-MISC', 'score': '0.983053', 'index': 10, 'word': 's', 'start': 34, 'end': 35}, {'entity': 'I-MISC', 'score': '0.8973793', 'index': 11, 'word': 'Eve', 'start': 36, 'end': 39}, {'entity': 'B-LOC', 'score': '0.9979153', 'index': 14, 'word': 'Times', 'start': 55, 'end': 60}, {'entity': 'I-LOC', 'score': '0.99908066', 'index': 15, 'word': 'Square', 'start': 61, 'end': 67}]
# ******
# [{'entity': 'B-PER',
#   'score': '0.59498155',
#   'index': 1,
#   'word': 'Confetti',
#   'start': 0,
#   'end': 8},
#  {'entity': 'B-MISC',
#   'score': '0.6991049',
#   'index': 7,
#   'word': "New Year's Eve",
#   'start': 25,
#   'end': 39},
#  {'entity': 'B-LOC',
#   'score': '0.9979153',
#   'index': 14,
#   'word': 'Times Square',
#   'start': 55,
#   'end': 67}]

# %%
sub_words = []

def post_processing(row):
    # merge NER
    ner_list, text = row["NER"], row["text"]
    result = merge_adjacent_ner(ner_list, text)
    
     
    row["NER"] = result
    return row

def print_rows(df):
    for x in df.iterrows():
        original = x[1]["NER"]
        row = post_processing(x[1])

        if row["NER"]:
            word = [x["word"] for x in row["NER"]] 
            score = [x["score"] for x in row["NER"]] 

            print(x[0])
            print(x[1]["text"])
            print("original: " + str([y["word"] for y in original]))
            print("processed: " + str(word))
            print("score: " + str(score))
            print()

# %%
# 3. report (half people half org)
post_processed_data = e_sizes.apply(post_processing, axis = 1)

# %%
print_rows(post_processed_data[500:600])
# Out:
# 693
# The Ugly History of New Year’s Is Too Real for White GOPers
# original: ['Ugly History of New Year’s']
# processed: ['Ugly History of New Year’s']
# score: ['0.6156665']
#
# 695
# Enslaved Black people dreaded New Year’s in Civil War-era America, when they might be separated from loved ones. Just don’t tell the people yelling about “critical race theory.”
# original: ['Black', 'Civil War-era', 'America']
# processed: ['Black', 'Civil War-era', 'America']
# score: ['0.99879706', '0.9985281', '0.99925584']
#
# 697
# Betty White, Everybody’s Favorite Foxy Grandmother, Has Died
# original: ['Betty White']
# processed: ['Betty White']
# score: ['0.99536884']
#
# 701
# Take a Moment From Your Vacation, Ron, and Reassure Florida
# original: ['Ron', 'Florida']
# processed: ['Ron', 'Florida']
# score: ['0.99628437', '0.86698437']
#
# 704
# The 11 Best Movies of the Year
# original: ['Best Movies of the']
# processed: ['Best Movies of the']
# score: ['0.78730094']
#
# 710
# What’s With All the Singing in ‘Emily in Paris?’
# original: ['Paris']
# processed: ['Paris']
# score: ['0.9995363']
#
# 713
# Is Dyson’s Online Outlet the Internet’s Best Kept Secret?
# original: ['Dyson’s', 'Online Outlet', 'Internet’s Best Kept Secret']
# processed: ['Dyson’s', 'Online Outlet', 'Internet’s Best Kept Secret']
# score: ['0.5265316', '0.5915585', '0.71150726']
#
# 745
# ‘The moments to seize hold of’: Essayists Brewster and Klose raise an ode to joy
# original: ['Brewster', 'Klose']
# processed: ['Brewster', 'Klose']
# score: ['0.99774325', '0.77549887']
#
# 752
# ‘Values became a bedrock’: Ann Scott Tyson on the Afghan Scouts who stayed to serve
# original: ['Ann Scott Tyson', 'Afghan Scouts']
# processed: ['Ann Scott Tyson', 'Afghan Scouts']
# score: ['0.99773645', '0.505861']
#
# 753
# From ‘King Richard’ to ‘Gunda’: The 10 best films of 2021
# original: ['Richard', 'Gunda']
# processed: ['Richard', 'Gunda']
# score: ['0.99075127', '0.48710456']
#
# 754
# A year of resilience: Monitor photographers reflect on 2021
# original: ['Monitor']
# processed: ['Monitor']
# score: ['0.994787']
#
# 756
# Working across the aisle, lawmakers deliver wins for North Carolina
# original: ['North Carolina']
# processed: ['North Carolina']
# score: ['0.99874675']
#
# 768
# Russian court shuts down Memorial, a renowned human rights group
# original: ['Russian', 'Memorial']
# processed: ['Russian', 'Memorial']
# score: ['0.9997098', '0.9989219']
#
# 770
# Polish president vetoes media bill threatening US company
# original: ['Polish', 'US']
# processed: ['Polish', 'US']
# score: ['0.9997205', '0.95114404']
#
# 771
# Desmond Tutu: Anti-apartheid icon and moral compass for a nation
# original: ['Desmond Tutu']
# processed: ['Desmond Tutu']
# score: ['0.9884928']
#
# 773
# Webb Space Telescope: How is it different from Hubble?
# original: ['Webb Space Telescope', 'Hubble']
# processed: ['Webb Space Telescope', 'Hubble']
# score: ['0.9951114', '0.9748632']
#
# 774
# One neighborhood reaches for resilience: A letter from Chicago
# original: ['Chicago']
# processed: ['Chicago']
# score: ['0.9990331']
#
# 775
# Iran nuclear talks: Is US following path that failed with North Korea?
# original: ['Iran', 'US', 'North Korea']
# processed: ['Iran', 'US', 'North Korea']
# score: ['0.99984396', '0.997767', '0.99939466']

# %%
# remove reCAPTCHA
post_processed_data = post_processed_data[["reCAPTCHA" not in x for x in df_frontpage["text"]]]

# %%
post_processed_data.to_pickle('./processed_data/elements_stats.pkl')
